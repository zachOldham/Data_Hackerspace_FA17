# %% [markdown]
# # Web Scraping

# %%
# What you've seen before
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

# What's new
from bs4 import BeautifulSoup # We'll be using this to scrape through HTML documents
import re # We'll be using regular expressions (a bit) to search through text
import networkx as nx # We'll be using this to graph a website (not super important)

# %% [markdown]
# ## Example 1: Hacker News

# %%
html_doc = requests.get('https://news.ycombinator.com/').text
html_doc
# Out:
# '<html op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?543QKAqoJKX29blpuDlq">\n        <link rel="shortcut icon" href="favicon.ico">\n          <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">\n        <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">\n        <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>\n                  <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>\n              <a href="newest">new</a> | <a href="newcomments">comments</a> | <a href="show">show</a> | <a href="ask">ask</a> | <a href="jobs">jobs</a> | <a href="submit">submit</a>            </span></td><td style="text-align:right;padding-right:4px;"><span class="pagetop">\n                              <a href="login?goto=news">login</a>\n                          </span></td>\n              </tr></table></td></tr>\n<tr style="height:10px"></tr><tr><td><table border="0" cellpadding="0" cellspacing="0" class="itemlist">\n              <tr class=\'athing\' id=\'15453974\'>\n      <td align="right" valign="top" class="title"><span class="rank">1.</span></td>      <td valign="top" class="votelinks"><center><a id=\'up_15453974\' href=\'vote?id=15453974&amp;how=up&amp;goto=news\'><div class=\'votearrow\' title=\'upvote\'></div></a></center></td><td class="title"><a href="http://www.pleasetakecareofmyplant.com/" class="storylink">Please take care of my plant</a><span class="sitebit comhead"> (<a href="from?site=pleasetakecareofmyplant.com"><span class="sitestr">pleasetakecareofmyplant.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">\n        <span class="score" id="score_15453974">178 points</span> by <a href="user?id=mooreds" class="hnuser">mooreds</a> <span class="age"><a href="item?id=15453974">2 hours ago</a></span> <span id="unv_15453974"></span> | <a href="hide?id=15453974&amp;goto=news">hide</a> | <a href="item?id=15453974">22&nbsp;comments</a>              </td></tr>\n      <tr class="spacer" style="height:5px"></tr>\n                <tr class=\'athing\' id=\'15454352\'>\n      <td align="right" valign="top" class="title"><span class="rank">2.</span></td>      <td valign="top" class="votelinks"><center><a id=\'up_15454352\' href=\'vote?id=15454352&amp;how=up&amp;goto=news\'><div class=\'votearrow\' title=\'upvote\'></div></a></center></td><td class="title"><a href="https://matthias-endler.de/2017/yes/" class="storylink">A Little Story About the `yes` Unix Command</a><span class="sitebit comhead"> (<a href="from?site=matthias-endler.de"><span class="sitestr">matthias-endler.de</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">\n        <span class="score" id="score_15454352">28 points</span> by <a href="user?id=omn1" class="hnuser">omn1</a> <span class="age"><a href="item?id=15454352">40 minutes ago</a></span> <span id="unv_15454352"></span> | <a href="hide?id=15454352&amp;goto=news">hide</a> | <a href="item?id=15454352">7&nbsp;comments</a>              </td></tr>\n      <tr class="spacer" style="height:5px"></tr>\n                <tr class=\'athing\' id=\'15454252\'>\n      <td align="right" valign="top" class="title"><span class="rank">3.</span></td>      <td valign="top" class="votelinks"><center><a id=\'up_15454252\' href=\'vote?id=15454252&amp;how=up&amp;goto=news\'><div class=\'votearrow\' title=\'upvote\'></div></a></center></td><td class="title"><a href="https://www.wsj.com/articles/beijing-pushes-for-a-direct-hand-in-chinas-big-tech-firms-1507758314" class="sto ...

# %% [markdown]
# ### Basic Document Information

# %%
soup = BeautifulSoup(html_doc, "html5lib")
print(soup.title) # Find the 'title' tag
print(soup.title.string) # Find the 'title' tag's text value
# Out:
# <title>Hacker News</title>
# Hacker News

# %%
# We can get all the text from elements in the HTML
# to get an easy dataset for the webpage's text content
print(soup.get_text())
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | comments | show | ask | jobs | submit
#                               login
#
#
#
#
#       1.      Please take care of my plant (pleasetakecareofmyplant.com)
#         178 points by mooreds 2 hours ago  | hide | 22 comments
#
#
#       2.      A Little Story About the `yes` Unix Command (matthias-endler.de)
#         28 points by omn1 40 minutes ago  | hide | 7 comments
#
#
#       3.      Beijing Pushes for a Direct Hand in Big Chinese Tech Firms (wsj.com)
#         32 points by petethomas 1 hour ago  | hide | 16 comments
#
#
#       4.      Competitive Self-Play (openai.com)
#         216 points by gdb 6 hours ago  | hide | 77 comments
#
#
#       5.      Firefox Send: Private, Encrypted File Sharing (firefox.com)
#         630 points by networked 12 hours ago  | hide | 219 comments
#
#
#       6.      Ansible open-sources Ansible Tower with AWX (jeffgeerling.com)
#         186 points by sciurus 8 hours ago  | hide | 74 comments
#
#
#       7.      Symantec CEO says source code reviews by foreign states pose unacceptable risk (reuters.com)
#         99 points by ohjeez 7 hours ago  | hide | 71 comments
#
#
#       8.      Western news about China depends on intrepid Chinese ‘news assistants’ (qz.com)
#         39 points by sohkamyung 3 hours ago  | hide | 17 comments
#
#
#       9.      HelloSign Is Hiring Engineers (Elixir or PHP) (San Francisco) (lever.co)
#         23 minutes ago | hide
#
#
#       10.      The Depression Thing (zachholman.com)
#         461 points by darwhy 7 hours ago  | hide | 225 comments
#
#
#       11.      Evidence That Online Dating Is Changing Society (technologyreview.com)
#         90 points by dtawfik1 4 hours ago  | hide | 51 comments
#
#
#       12.      Scientists Can Read a Bird’s Brain and Predict Its Next Song (technologyreview.com)
#         30 points by aq3cn 3 hours ago  | hide | discuss
#
#
#       13.      RIP the Broccoli Tree (kottke.org)
#         298 points by panic 5 hours ago  | hide | 99 comments
#
#
#       14.      An algebraic generalization for graph and tensor-based neural networks [pdf] (cibcb2017.org)
#         81 points by Katydid 6 hours ago  | hide | 9 comments
#
#
#       15.      Functor-Oriented Programming (r6.ca)
#         90 points by szatkus 6 hours ago  | hide | 17 comments
#
#
#       16.      Let's enable AppArmor by default (why not?) (debian.org)
#         78 points by boramalper 3 hours ago  | hide | 43 comments
#
#
#       17.      Broken packets: IP fragmentation is flawed (cloudflare.com)
#         76 points by majke 6 hours ago  | hide | 29 comments
#
#
#       18.      Ask HN: What non-work task have you automated?
#         272 points by Kevin_S 6 hours ago  | hide | 380 comments
#
#
#       19.      The Ainu, the Indigenous people of Japan (hakaimagazine.com)
#         173 points by sohkamyung 11 hours ago  | hide | 82 comments
#
#
#       20.      Cthulhu: Organizing Go Code in a Scalable Repo (digitalocean.com)
#         66 points by jsvcycling 6 hours ago  | hide | discuss
#
#
#       21.      The privilege of risk (edtechie.net)
#         86 points by fs111 4 hours ago  | hide | 48 comments
#
#
#       22.      Why Stanford Researchers Tried to Create a ‘Gaydar’ Machine (nytimes.com)
#         4 points by JumpCrisscross 1 hour ago  | hide | discuss
#
#
#       23.      What happened to distributed programming languages? [video] (youtube.com)
#         8 points by panic 1 hour ago  | hide | discuss
#
#
#       24.      Inside the World’s Largest Walnut Forest (roadsandkingdoms.com)
#         26 points by fern12 4 hours ago  | hide | 6 comments
#
#
#       25.      Dropbox taking entire building in Mission Bay – biggest lease in city history (sfchronicle.com)
#         102 points by minimaxir 4 hours ago  | hide | 103 comments
#
#
#       26.      Roman Empire per capita GDP shows the Romans were poorer than any 2015 country (brilliantmaps.com)
#         60 points by ThomPete 7 hours ago  | hide | 98 comments
#
#
#       27.      GitHub Discover (github.com)
#         110 points by uyoakaoma 6 hours ago  | hide | 27 comments
#
#
#       28.      Elliptic Curve Cryptography for Beginners (wesleyac.com)
#         285 points by deafcalculus 14 hours ago  | hide | 25 comments
#
#
#       29.      RxFiddle: Visualize your Observables (rxfiddle.net)
#         18 points by pbadenski 3 hours ago  | hide | 1 comment
#
#
#       30.      Introducing Oculus Go, Plus Santa Cruz Updates (oculus.com)
#         175 points by runesoerensen 6 hours ago  | hide | 170 comments
#
#             More
#
#
# Guidelines
#         | FAQ
#         | Support
#         | API
#         | Security
#         | Lists
#         | Bookmarklet
#         | DMCA
#         | Apply to YC
#         | ContactSearch:

# %%
print(soup.a) # This gives us the first link ('a') tag in the document

# We can also iterate over all the link tags in a document
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# <a href="https://news.ycombinator.com"><img height="18" src="y18.gif" style="border:1px white solid;" width="18"/></a>
# https://news.ycombinator.com
# news
# newest
# newcomments
# show
# ask
# jobs
# submit
# login?goto=news
# vote?id=15453974&how=up&goto=news
# http://www.pleasetakecareofmyplant.com/
# from?site=pleasetakecareofmyplant.com
# user?id=mooreds
# item?id=15453974
# hide?id=15453974&goto=news
# item?id=15453974
# vote?id=15454352&how=up&goto=news
# https://matthias-endler.de/2017/yes/
# from?site=matthias-endler.de
# user?id=omn1
# item?id=15454352
# hide?id=15454352&goto=news
# item?id=15454352
# vote?id=15454252&how=up&goto=news
# https://www.wsj.com/articles/beijing-pushes-for-a-direct-hand-in-chinas-big-tech-firms-1507758314
# from?site=wsj.com
# user?id=petethomas
# item?id=15454252
# hide?id=15454252&goto=news
# item?id=15454252
# vote?id=15451584&how=up&goto=news
# https://blog.openai.com/competitive-self-play/?
# from?site=openai.com
# user?id=gdb
# item?id=15451584
# hide?id=15451584&goto=news
# item?id=15451584
# vote?id=15448996&how=up&goto=news
# https://send.firefox.com/
# from?site=firefox.com
# user?id=networked
# item?id=15448996
# hide?id=15448996&goto=news
# item?id=15448996
# vote?id=15450594&how=up&goto=news
# https://www.jeffgeerling.com/blog/2017/ansible-open-sources-ansible-tower-awx
# from?site=jeffgeerling.com
# user?id=sciurus
# item?id=15450594
# hide?id=15450594&goto=news
# item?id=15450594
# vote?id=15450870&how=up&goto=news
# http://www.reuters.com/article/us-usa-cyber-russia-symantec/exclusive-symantec-ceo-says-source-code-reviews-pose-unacceptable-risk-idUSKBN1CF2SB
# from?site=reuters.com
# user?id=ohjeez
# item?id=15450870
# hide?id=15450870&goto=news
# item?id=15450870
# vote?id=15447432&how=up&goto=news
# https://qz.com/1094098/why-you-dont-know-the-names-of-the-people-who-take-the-biggest-risks-to-bring-you-your-china-news/
# from?site=qz.com
# user?id=sohkamyung
# item?id=15447432
# hide?id=15447432&goto=news
# item?id=15447432
# https://jobs.lever.co/hellosign?lever-origin=applied&lever-source%5B%5D=HackerNews
# from?site=lever.co
# item?id=15454568
# hide?id=15454568&goto=news
# vote?id=15451060&how=up&goto=news
# http://zachholman.com/posts/the-depression-thing
# from?site=zachholman.com
# user?id=darwhy
# item?id=15451060
# hide?id=15451060&goto=news
# item?id=15451060
# vote?id=15452536&how=up&goto=news
# https://www.technologyreview.com/s/609091/first-evidence-that-online-dating-is-changing-the-nature-of-society/
# from?site=technologyreview.com
# user?id=dtawfik1
# item?id=15452536
# hide?id=15452536&goto=news
# item?id=15452536
# vote?id=15447405&how=up&goto=news
# https://www.technologyreview.com/s/609032/scientists-can-read-a-birds-brain-and-predict-its-next-song/
# from?site=technologyreview.com
# user?id=aq3cn
# item?id=15447405
# hide?id=15447405&goto=news
# item?id=15447405
# vote?id=15452138&how=up&goto=news
# https://kottke.org/17/09/rip-the-broccoli-tree
# from?site=kottke.org
# user?id=panic
# item?id=15452138
# hide?id=15452138&goto=news
# item?id=15452138
# vote?id=15451601&how=up&goto=news
# http://www.cibcb2017.org/slides/CIBCB-2017-Ethan-Aug23.pdf
# from?site=cibcb2017.org
# user?id=Katydid
# item?id=15451601
# hide?id=15451601&goto=news
# item?id=15451601
# vote?id=15440108&how=up&goto=news
# http://r6.ca/blog/20171010T001746Z.html
# from?site=r6.ca
# user?id=szatkus
# item?id=15440108
# hide?id=15440108&goto=news
# item?id=15440108
# vote?id=15453454&how=up&goto=news
# https://lists.debian.org/debian-devel/2017/08/msg00090.html
# from?site=debian.org
# user?id=boramalper
# item?id=15453454
# hide?id=15453454&goto=news
# item?id=15453454
# vote?id=15448960&how=up&goto=news
# https://blog.cloudflare.com/ip-fragmentation-is-broken/
# from?site=cloudflare.com
# user?id=majke
# item?id=15448960
# hide?id=15448960&goto=news
# item?id=15448960
# vote?id=15451442&how=up&goto=news
# item?id=15451442
# user?id=Kevin_S
# item?id=15451442
# hide?id=15451442&goto=news
# item?id=15451442
# vote?id=15440125&how=up&goto=news
# https://www.hakaimagazine.com/features/prejudice-pride
# from?site=hakaimagazine.com
# user?id=sohkamyung
# item?id=15440125
# hide?id=15440125&goto=news
# item?id=15440125
# vote?id=15451180&how=up&goto=news
# https://blog.digitalocean.com/cthulhu-organizing-go-code-in-a-scalable-repo/
# from?site=digitalocean.com
# user?id=jsvcycling
# item?id=15451180
# hide?id=15451180&goto=news
# item?id=15451180
# vote?id=15440433&how=up&goto=news
# http://blog.edtechie.net/asides/the-privilege-of-risk/
# from?site=edtechie.net
# user?id=fs111
# item?id=15440433
# hide?id=15440433&goto=news
# item?id=15440433
# vote?id=15449119&how=up&goto=news
# https://www.nytimes.com/2017/10/09/science/stanford-sexual-orientation-study.html
# from?site=nytimes.com
# user?id=JumpCrisscross
# item?id=15449119
# hide?id=15449119&goto=news
# item?id=15449119
# vote?id=15450928&how=up&goto=news
# https://www.youtube.com/watch?v=eAcDWcaezXY
# from?site=youtube.com
# user?id=panic
# item?id=15450928
# hide?id=15450928&goto=news
# item?id=15450928
# vote?id=15447719&how=up&goto=news
# http://roadsandkingdoms.com/2017/inside-the-worlds-largest-walnut-forest/
# from?site=roadsandkingdoms.com
# user?id=fern12
# item?id=15447719
# hide?id=15447719&goto=news
# item?id=15447719
# vote?id=15446471&how=up&goto=news
# http://www.sfchronicle.com/bayarea/article/Dropbox-taking-entire-building-in-Mission-Bay-12267749.php
# from?site=sfchronicle.com
# user?id=minimaxir
# item?id=15446471
# hide?id=15446471&goto=news
# item?id=15446471
# vote?id=15449301&how=up&goto=news
# http://brilliantmaps.com/roman-empire-gdp/
# from?site=brilliantmaps.com
# user?id=ThomPete
# item?id=15449301
# hide?id=15449301&goto=news
# item?id=15449301
# vote?id=15451371&how=up&goto=news
# https://github.com/dashboard/discover
# from?site=github.com
# user?id=uyoakaoma
# item?id=15451371
# hide?id=15451371&goto=news
# item?id=15451371
# vote?id=15440170&how=up&goto=news
# http://blog.wesleyac.com/posts/elliptic-curves
# from?site=wesleyac.com
# user?id=deafcalculus
# item?id=15440170
# hide?id=15440170&goto=news
# item?id=15440170
# vote?id=15440631&how=up&goto=news
# https://rxfiddle.net/#type=editor&code=...
# from?site=rxfiddle.net
# user?id=pbadenski
# item?id=15440631
# hide?id=15440631&goto=news
# item?id=15440631
# vote?id=15451400&how=up&goto=news
# https://www.oculus.com/blog/pioneering-the-frontier-of-vr-introducing-oculus-go-plus-santa-cruz-updates/
# from?site=oculus.com
# user?id=runesoerensen
# item?id=15451400
# hide?id=15451400&goto=news
# item?id=15451400
# news?p=2
# newsguidelines.html
# newsfaq.html
# mailto:hn@ycombinator.com
# https://github.com/HackerNews/API
# security.html
# lists
# bookmarklet.html
# dmca.html
# http://www.ycombinator.com/apply/
# mailto:hn@ycombinator.com

# %%
# Suppose we know the class of an element we want to search for.
# We can pass that in as a parameter to narrow our search
for story_link in soup.find_all('a', {'class': 'storylink'}):
    print(story_link.text, story_link.get('href'))
# Out:
# Please take care of my plant http://www.pleasetakecareofmyplant.com/
# A Little Story About the `yes` Unix Command https://matthias-endler.de/2017/yes/
# Beijing Pushes for a Direct Hand in Big Chinese Tech Firms https://www.wsj.com/articles/beijing-pushes-for-a-direct-hand-in-chinas-big-tech-firms-1507758314
# Competitive Self-Play https://blog.openai.com/competitive-self-play/?
# Firefox Send: Private, Encrypted File Sharing https://send.firefox.com/
# Ansible open-sources Ansible Tower with AWX https://www.jeffgeerling.com/blog/2017/ansible-open-sources-ansible-tower-awx
# Symantec CEO says source code reviews by foreign states pose unacceptable risk http://www.reuters.com/article/us-usa-cyber-russia-symantec/exclusive-symantec-ceo-says-source-code-reviews-pose-unacceptable-risk-idUSKBN1CF2SB
# Western news about China depends on intrepid Chinese ‘news assistants’ https://qz.com/1094098/why-you-dont-know-the-names-of-the-people-who-take-the-biggest-risks-to-bring-you-your-china-news/
# HelloSign Is Hiring Engineers (Elixir or PHP) (San Francisco) https://jobs.lever.co/hellosign?lever-origin=applied&lever-source%5B%5D=HackerNews
# The Depression Thing http://zachholman.com/posts/the-depression-thing
# Evidence That Online Dating Is Changing Society https://www.technologyreview.com/s/609091/first-evidence-that-online-dating-is-changing-the-nature-of-society/
# Scientists Can Read a Bird’s Brain and Predict Its Next Song https://www.technologyreview.com/s/609032/scientists-can-read-a-birds-brain-and-predict-its-next-song/
# RIP the Broccoli Tree https://kottke.org/17/09/rip-the-broccoli-tree
# An algebraic generalization for graph and tensor-based neural networks [pdf] http://www.cibcb2017.org/slides/CIBCB-2017-Ethan-Aug23.pdf
# Functor-Oriented Programming http://r6.ca/blog/20171010T001746Z.html
# Let's enable AppArmor by default (why not?) https://lists.debian.org/debian-devel/2017/08/msg00090.html
# Broken packets: IP fragmentation is flawed https://blog.cloudflare.com/ip-fragmentation-is-broken/
# Ask HN: What non-work task have you automated? item?id=15451442
# The Ainu, the Indigenous people of Japan https://www.hakaimagazine.com/features/prejudice-pride
# Cthulhu: Organizing Go Code in a Scalable Repo https://blog.digitalocean.com/cthulhu-organizing-go-code-in-a-scalable-repo/
# The privilege of risk http://blog.edtechie.net/asides/the-privilege-of-risk/
# Why Stanford Researchers Tried to Create a ‘Gaydar’ Machine https://www.nytimes.com/2017/10/09/science/stanford-sexual-orientation-study.html
# What happened to distributed programming languages? [video] https://www.youtube.com/watch?v=eAcDWcaezXY
# Inside the World’s Largest Walnut Forest http://roadsandkingdoms.com/2017/inside-the-worlds-largest-walnut-forest/
# Dropbox taking entire building in Mission Bay – biggest lease in city history http://www.sfchronicle.com/bayarea/article/Dropbox-taking-entire-building-in-Mission-Bay-12267749.php
# Roman Empire per capita GDP shows the Romans were poorer than any 2015 country http://brilliantmaps.com/roman-empire-gdp/
# GitHub Discover https://github.com/dashboard/discover
# Elliptic Curve Cryptography for Beginners http://blog.wesleyac.com/posts/elliptic-curves
# RxFiddle: Visualize your Observables https://rxfiddle.net/#type=editor&code=...
# Introducing Oculus Go, Plus Santa Cruz Updates https://www.oculus.com/blog/pioneering-the-frontier-of-vr-introducing-oculus-go-plus-santa-cruz-updates/

# %%
stories = []
for news_row in soup.find_all('tr', {'class': 'athing'}):
    # We can use the same commands on children nodes of the document
    # (.find() returns the first found result)
    story = news_row.find('a', {'class': 'storylink'})
    story_name, story_link = story.text, story.get('href')

    # We're not restricted just to searching up and down the document,
    # We can search accross 'siblings'
    meta_data_row = news_row.find_next_sibling('tr')
    
    score, comments = None, None
    
    # Need to check if the story has a score
    if meta_data_row.find('span', {'class': 'score'}):
        score = int(meta_data_row.find('span', {'class': 'score'}).text.split()[0])
    
    # If you know regular expressions, you can use those to search for patterns
    # in the document
    comments_pattern = re.compile(r'comments')
    if meta_data_row.find('a', text=comments_pattern):
        comments = int(meta_data_row.find('a', text=comments_pattern).text.split()[0])
    
    stories.append({
            'name': story_name,
            'link': story_link,
            'score': score,
            'comments': comments
        })
stories
# Out:
# [{'comments': 22,
#   'link': 'http://www.pleasetakecareofmyplant.com/',
#   'name': 'Please take care of my plant',
#   'score': 178},
#  {'comments': 7,
#   'link': 'https://matthias-endler.de/2017/yes/',
#   'name': 'A Little Story About the `yes` Unix Command',
#   'score': 28},
#  {'comments': 16,
#   'link': 'https://www.wsj.com/articles/beijing-pushes-for-a-direct-hand-in-chinas-big-tech-firms-1507758314',
#   'name': 'Beijing Pushes for a Direct Hand in Big Chinese Tech Firms',
#   'score': 32},
#  {'comments': 77,
#   'link': 'https://blog.openai.com/competitive-self-play/?',
#   'name': 'Competitive Self-Play',
#   'score': 216},
#  {'comments': 219,
#   'link': 'https://send.firefox.com/',
#   'name': 'Firefox Send: Private, Encrypted File Sharing',
#   'score': 630},
#  {'comments': 74,
#   'link': 'https://www.jeffgeerling.com/blog/2017/ansible-open-sources-ansible-tower-awx',
#   'name': 'Ansible open-sources Ansible Tower with AWX',
#   'score': 186},
#  {'comments': 71,
#   'link': 'http://www.reuters.com/article/us-usa-cyber-russia-symantec/exclusive-symantec-ceo-says-source-code-reviews-pose-unacceptable-risk-idUSKBN1CF2SB',
#   'name': 'Symantec CEO says source code reviews by foreign states pose unacceptable risk',
#   'score': 99},
#  {'comments': 17,
#   'link': 'https://qz.com/1094098/why-you-dont-know-the-names-of-the-people-who-take-the-biggest-risks-to-bring-you-your-china-news/',
#   'name': 'Western news about China depends on intrepid Chinese ‘news assistants’',
#   'score': 39},
#  {'comments': None,
#   'link': 'https://jobs.lever.co/hellosign?lever-origin=applied&lever-source%5B%5D=HackerNews',
#   'name': 'HelloSign Is Hiring Engineers (Elixir or PHP) (San Francisco)',
#   'score': None},
#  {'comments': 225,
#   'link': 'http://zachholman.com/posts/the-depression-thing',
#   'name': 'The Depression Thing',
#   'score': 461},
#  {'comments': 51,
#   'link': 'https://www.technologyreview.com/s/609091/first-evidence-that-online-dating-is-changing-the-nature-of-society/',
#   'name': 'Evidence That Online Dating Is Changing Society',
#   'score': 90},
#  {'comments': None,
#   'link': 'https://www.technologyreview.com/s/609032/scientists-can-read-a-birds-brain-and-predict-its-next-song/',
#   'name': 'Scientists Can Read a Bird’s Brain and Predict Its Next Song',
#   'score': 30},
#  {'comments': 99,
#   'link': 'https://kottke.org/17/09/rip-the-broccoli-tree',
#   'name': 'RIP the Broccoli Tree',
#   'score': 298},
#  {'comments': 9,
#   'link': 'http://www.cibcb2017.org/slides/CIBCB-2017-Ethan-Aug23.pdf',
#   'name': 'An algebraic generalization for graph and tensor-based neural networks [pdf]',
#   'score': 81},
#  {'comments': 17,
#   'link': 'http://r6.ca/blog/20171010T001746Z.html',
#   'name': 'Functor-Oriented Programming',
#   'score': 90},
#  {'comments': 43,
#   'link': 'https://lists.debian.org/debian-devel/2017/08/msg00090.html',
#   'name': "Let's enable AppArmor by default (why not?)",
#   'score': 78},
#  {'comments': 29,
#   'link': 'https://blog.cloudflare.com/ip-fragmentation-is-broken/',
#   'name': 'Broken packets: IP fragmentation is flawed',
#   'score': 76},
#  {'comments': 380,
#   'link': 'item?id=15451442',
#   'name': 'Ask HN: What non-work task have you automated?',
#   'score': 272},
#  {'comments': 82,
#   'link': 'https://www.hakaimagazine.com/features/prejudice-pride',
#   'name': 'The Ainu, the Indigenous people of Japan',
#   'score': 173},
#  {'comments': None,
#   'link': 'https://blog.digitalocean.com/cthulhu-organizing-go-code-in-a-scalable-repo/',
#   'name': 'Cthulhu: Organizing Go Code in a Scalable Repo',
#   'score': 66},
#  {'comments': 48,
#   'link': 'http://blog.edtechie.net/asides/the-privilege-of-risk/',
#   'name': 'The privilege of risk',
#   'score': 86},
#  {'comments': None,
#   'link': 'https://www.nytimes.com/2017/10/09/science/stanford-sexual-orientation-study.html',
#   'name': 'Why Stanford Researchers Tried to Create a ‘Gaydar’ Machine',
#   'score': 4},
#  {'comments': None,
#   'link': 'https://www.youtube.com/watch?v=eAcDWcaezXY',
#   'name': 'What happened to distributed programming languages? [video]',
#   'score': 8},
#  {'comments': 6,
#   'link': 'http://roadsandkingdoms.com/2017/inside-the-worlds-largest-walnut-forest/',
#   'name': 'Inside the World’s Largest Walnut Forest',
#   'score': 26},
#  {'comments': 103,
#   'link': 'http://www.sfchronicle.com/bayarea/article/Dropbox-taking-entire-building-in-Mission-Bay-12267749.php',
#   'name': 'Dropbox taking entire building in Mission Bay – biggest lease in city history',
#   'score': 102},
#  {'comments': 98,
#   'link': 'http://brilliantmaps.com/roman-empire-gdp/',
#   'name': 'Roman Empire per capita GDP shows the Romans were poorer than any 2015 country',
#   'score': 60},
#  {'comments': 27,
#   'link': 'https://github.com/dashboard/discover',
#   'name': 'GitHub Discover',
#   'score': 110},
#  {'comments': 25,
#   'link': 'http://blog.wesleyac.com/posts/elliptic-curves',
#   'name': 'Elliptic Curve Cryptography for Beginners',
#   'score': 285},
#  {'comments': None,
#   'link': 'https://rxfiddle.net/#type=editor&code=...',
#   'name': 'RxFiddle: Visualize your Observables',
#   'score': 18},
#  {'comments': 170,
#   'link': 'https://www.oculus.com/blog/pioneering-the-frontier-of-vr-introducing-oculus-go-plus-santa-cruz-updates/',
#   'name': 'Introducing Oculus Go, Plus Santa Cruz Updates',
#   'score': 175}]

# %%
stories_df = pd.DataFrame(stories)
stories_df.plot.scatter('comments', 'score')

# %% [markdown]
# ## Example 2: Crawling the Web

# %%
### nyt_url = 'http://www.nytimes.com/'
nyt_links = {} # Dict to hold adjacent sites
links_to_scrape = [nyt_url] # Stack of links to visit

# Keep going while we still have links to visit, and we have
# 'seen' less than 1500 (unique) links
while links_to_scrape and len(nyt_links) < 600:
    # Grab the 'latest' link from our list
    scrape_page = links_to_scrape.pop()
    # Visit our link and make it into soup
    try:
        r = requests.get(scrape_page, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0 Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv:42.0) Gecko/20100101 Firefox/42.0'})
    except:
        continue
    soup = BeautifulSoup(r.text, "html5lib")
    
    # Iterate through all the links on the current page
    for link in soup.find_all('a'):
        try: 
            href = link.get('href') # Get the link's address
        except requests.exceptions.ConnectionError:
            print("Connection refused by the server..")
            print("Let me sleep for 5 seconds")
            print("ZZzzzz...")
            time.sleep(5)
            print("Was a nice sleep, now let me continue...")
            continue

        # Reject the link if invalid or doesn't start with 'http'
        if not href or not href.startswith('http'):
            continue
            
        # Have we already visited this link?
        if not href in nyt_links:
            nyt_links[href] = [scrape_page] # Initialize list of adjacent links
            
            # Save link to scrape later
            if href not in links_to_scrape:
                links_to_scrape.append(href)
        else:
            nyt_links[href].append(scrape_page) # Add link to adjacent links
            
    # Report how many links we've 'seen'
    print("Up to {} links.".format(len(nyt_links)))

print(nyt_links)
# Out:
# Up to 255 links.
# Up to 315 links.
# Up to 335 links.
# Up to 346 links.
# Up to 513 links.
# Up to 521 links.
# Up to 527 links.
# Up to 529 links.
# Up to 541 links.
# Up to 554 links.
# Up to 565 links.
# Up to 588 links.
# Up to 626 links.
# {'http://www.nytimes.com/content/help/site/ie9-support.html': ['http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'http://cn.nytimes.com': ['http://www.nytimes.com/'], 'https://www.nytimes.com/es/': ['http://www.nytimes.com/'], 'https://www.nytimes.com/': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html', 'http://www.nytimes.com/learning/general/feedback/index.html', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'http://www.nytimes.com/pages/todayspaper/index.html': ['http://www.nytimes.com/', 'https://www.nytimes.com/rss', 'http://homedelivery.nytimes.com'], 'https://www.nytimes.com/video': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'https://mobile.nytimes.com/', 'https://mobile.nytimes.com/', 'http://www.nytimes.com/content/help/rights/copyright/copyright-notice.html?nytmobile=0', 'http://www.nytimes.com/ref/membercenter/help/privacy.html', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/world': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/us': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/politics': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/nyregion': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/business': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/opinion': ['http://www.nytimes.com/', 'http://www.nytimes.com/'], 'https://www.nytimes.com/section/technology': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/science': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'https://mobile.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/health': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/sports': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/arts': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/fashion': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/pages/dining/index.html': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'https://mobile.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/travel': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'https://mobile.nytimes.com/', 'http://www.nytimes.com/learning/general/feedback/index.html'], 'https://www.nytimes.com/section/magazine': ['http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/', 'http://www.nytimes.com/ ...

# %%
# Plotting the graph (not super important to know in detail)

# Create a graph and feed it in our pages as nodes
nyt_graph = nx.Graph()
nyt_graph.add_nodes_from(nyt_links.keys())

# Add edges based on the 'adjacent' lists we created earlier
for node, adjacent in nyt_links.items():
    for a in adjacent:
        nyt_graph.add_edge(node, a)

with sns.axes_style('white'):
    fig = plt.subplots(1, figsize=(12,10))
    nx.draw_networkx(nyt_graph, edge_color='#a4a4a4', with_labels=False,
                     node_size=list(map(lambda x: len(x) * 10, nyt_links.values())))
    plt.axis('off')

# %% [markdown]
# # Challenges
# #### These may take you a bit longer! 😉
#
# ## Challenge 1: Subreddit Scraper
# Write a function that, given the name of a subreddit, will return you a DataFrame with the same data that we scraped from the HackerNews news page. (Story name / link, Score, and # of comments).
#
# (i.e. `subreddit_scraper('dataisbeautiful')` would be the function call)
#
# **NOTE**: You may want to use this in your request: `headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'}`

# %%
def subreddit_scraper(sub_str):
    pass

subreddit_scraper('dataisbeautiful')

# %% [markdown]
# ## Challenge 2: PyPI Parser
# *(PyPI is the indexer of popular python packages)*
#
# Write a function that, given the URL of a Python package, will return you a dictionary with the following package information:
# - Author
# - Release (upload) Date
# - License
# - Home Page
#
# (Note the possibility that not all of these fields will be present on all packages, and write your function accordingly)

# %%
def pypi_parser(pypi_url):
    pass

pypi_parser('https://pypi.python.org/pypi/beautifulsoup4/4.5.1')
pypi_parser('https://pypi.python.org/pypi/SQLAlchemy/1.1.0')

# %% [markdown]
# ## Challenge 3: IMDB Cast Data
# Write a function that, given the URL of a movie on IMDB will return you a list of the cast of the movie with the following information:
# - Actor name
# - Character name
# - Actor birthday
#
# Example:
# ```
# >>> imdb_cast('http://www.imdb.com/title/tt0796366/')
# [
#   {'actor': 'Chris Pine',
#   'character': 'Kirk',
#   'birthday': 'August 26, 1980'
#   }
#   ...
# ]
# ```

# %%
def imdb_cast(movie_url):
    pass
imdb_cast('http://www.imdb.com/title/tt0796366/')

# %% [markdown]
# <h2><center>That's it!</center></h2>
# ![nice_job](http://i.giphy.com/eoxomXXVL2S0E.gif)

# %% [markdown]
# ### Bonus Points:
# 1. For problem 1, write another function that uses the output of your function to plot the # of comments against the score of the post. Also, include a linear trend line. (Hint: `numpy.polyfit`)
# 2. For problem 2, include an array of all the published versions of the package in your return dictionary.
#
# *Important:* When you send us your solutions, let us know which (if any)
# of the bonus problems you've attempted.
